# %% [markdown]
# ## Scraping Youtube Video Transcripts
# Of course if the Youtube video has a transcript. This is a super simple thing to do. You'll need to have the youtube-transcript-api
# If you don't have it, go ahead and install through your command line, and come back.
# - pip install youtube-transcript-api
#
# If you have never used Python before and you need to get those transcripts bad, worry not. Just follow these steps and you'll be fine.
#
# First we will import the libraries, run the cell below:

# %%
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd

# %% [markdown]
# ## Great!
#
# Now we are going to make a list of the links we have gathered. These ids are the stuff that is after the watch= part of the Youtube link.
#
# For instance check this link out: https://www.youtube.com/watch?v=r6C8XZ4pW4s
# This is the first item in the list. You will have to generate a Youtube link list. That is on another tutorial.
#
# Let's be going. Run the cell below:

# %%
yt_links = ['r6C8XZ4pW4s', 'o_8pahoc3_w', '2Cr7eMt7aGI', 'joCjTRCq9HI', 'dN8AXdYXSC0', 'Bp770z04f4w', 'jKNovA4RiCk', '3ip7wXSfxx0', 'wet7aFsnKUY', 'gKoKPLLCE2s', 'FVy68Hnh6tc', 'tdmKEx8mQWQ', 'yF_R8382frM', 'bQXzZnjVAZM', 'Ub0gb31Y6wM', '8-iBasNl9Aw', 'hLaLHbi4jMk', '4XcY6z6YoSc', 'y4lUZK1YJNo', 'q_4Cjki3SOM', '16tPpd9jYzU', 'MqUemsuPP8U', 'zRPohxozYV0', 'N-zwdq45uhs', 'vqe0s9O_LaY', '9OKvK7bEJyQ', 'uLKShQDwHYY', 'WlsXTCCYne8', 'vwpkayOqbrI', 'VEV06tPL7C8', 'dIfolnlwFVs', 'xNzVeW2PgWI', 'eiGnfwiIQU4', 'Uo5yxmJk7gU', '9xxXqISRAWY', 'phO7_BRhJoI', 'tCgip6nnXHs', '5om3DP-kmB4', '-J0NQxnMrpo', 'GzQiLEfhNrU', 'rFIBY0tDoSg', 'SDsT6IjA1bM', 'KV2r84A8anI', '9MopbeWwvRc', 'iI6qaYDO4x4', '6tQvn11QHRg', '94ZffTVwLpA', 'A5ckbpDNZHM', '-mcmx_lcgQw', '2fu5Hl84Qdg', 'bHjVl6dZx8o', 'G0_Xdy_44cs', 'jEsrrA-4-0c', 'H9k81Art_5w', 'jIHApFKV7EA', 'bYE-45oVEvY', 'VLCTv_cv-jk', 'WkQbDOVMSJ0', 'YOvWq8ggfa0', 'lmH1ZPiAaGg', 't50jjhiMnlQ', '261VgCIFK70', 'lqOYCdSgy5g', '5YwbdyoRM_0', '1J7jZI0mhTg', '4wqCXNktGl8', 'eD9w3Cl5SYc', 'i_HYCHw5GYk', 'Gmuo2PxLzUQ', 'ZbVlb6J6VNk', 'gSXuhQQ7Yxo', 'gamkpbHtQEo', 'trUrqMRXHsE', 'HRbxJEVTkyE', 'pIbjw5UITAE', 'tj0LvQTZiUM', 'DzG6x1KtWoM', 'crFzedb_IOw', '7BYuC_8iIes', 'OG7ITMkJtA4', 'QUeRIhlMkZI', 'qAh9cEu8F7g', 'PbLByySb_mw', 'h8sT_un2EQ4', 'BBy7MH86Dtg', 'u20txO3rzNY', 'Asqkkn-gRFo', '5nxJVISJYos', 'xn4s4JiTSos', 'wpgNx3JR0mM', 'dD4Jtd1idIU', 'IslcdxjM_kU', 'w9CTg_XQ5uA', 'djNJufsrmDU', 'w83fK_F1Nf0', 'isnsUr1n_ZQ', 'WIOanNO3wws', 'aBgbfjw-T3Q', 'jn6Cg8aRpJU', 'JL0baATwigE', '87XJ8m54WnE', '_NxlgGfcYzA', '1Zqw2N1Fves', 'r9krgOQoRGg', '5EKH0O9c7M0', 'wmbT5Im7v70', 'WffMmL2TMy4', 'JFqP4n9ulIk', 'nntc-DoMhfU', 'VF_R_1qZ3hQ', 'JFqP4n9ulIk', 'VF_R_1qZ3hQ', 'e6xv9mKrIIk', '5O-rNqir9Ls', 'e_hxbbXv-gk', '1JS7GuroDR0', 'USS8NP68zG4', 'vbKQoqg16WY', 'GqT-eOnxNxU', 'y53pT5mLUQQ', 'fzFvy7wi1U4', 'OlReJ7fY5nU', 'rprqrte6A_k', 'wAhR600uq64', 'NAo7gdHJlMg', 'lGC8G-es5d0', '-e_secPfW7U', 'VDbmz7j_-yo', 'qizf-MfeYPk', 'f1FF0neoHUY', 'U7XuatDUwls', 'gFbzqHX5mno', 'jZL4mVtSgQU', 'a9NXFfyjzIo', 'NAo7gdHJlMg', 'sXpA7EUSVOg', 'Yh5YDC9hNYM', 'FNXAT8lFtf4', 'GqT-eOnxNxU', 'QjMW2697Kek', 'w05V6Iw2dD4', 'kdcsCFFK18Y', 'TKDqX9uF4Zg', 'PE5P6gYFSys', 'kCgnelhcGWM', 'bb30Sm2n8Ls', 'HMGw1Y8AmT8', 'HMGw1Y8AmT8', '1kaazMR2zzk', 'OD4i4CZJ1ho', 'AT0lAA77uZs', 'lI1bBnpZOOc', 'CAxm_P_kqC0', 'n8ZE0Zj-0Ig', 'VOa4Zzikfa0', '8GGTaZy9RD8', '7vTrjKty6vg', '-IsoBWb5aPY', 'nu0dTZDG9ig', 'utJK2vswX-k', 'KS-PIJ7BfIQ', '7duy3vXY9l0', 'hW61_s_mccE', '5KZYqXAV1g0', 'sifDon2pAiI', 'KqnevqfFhJI', 'pTmPg1twVuk', 'WKZa3PvwD50', '58uzWQ0JRNg', 'vFbnYaRPuMA', 'Brq0LaonZfM', 't1-A8jUYzIE', 'UsJQbq15jhY', 'KsFOAJsFgY4', '7L9Qyj2Y_Iw', '3jlhlgcJ2wY', 'edjdMKiHKms', 'jl_YKPe7u7g', 'YtbkusUEOmk', 'RLb1PAuDaiA', 'Y70-jCMiJek', 'UxYD5BgoQ4c', 'Zb7RkOwkCzU', 'S6mOsaJmS8M', '4lL17HcU8qg', 'lZi9WuQjA-Q', 'HR0TgMbY3mE', 'TY6I5Vj6w4M', 'P_Vel_hf4tg', '2HEG27Hu0tg', 'c3NRoO1SyEM', 'Ur-uxn3eMs8', '5Ve2suSEhu8', '0dkWi1o9AvA', '3VyS-G8skXg', '905mMboTUfs', '5Pdip2_pWj8', 'QrqQSntAnbQ', 'mbT1nn89lso', 'wBbjjlGiERM', 'QHoT8NMn_Gs', 'C2LoP2oIodM', '1tzDC3FXTqU', 'dKO89QRoYrE', '5O_8fWh-3K0', 'F2FQoNLO4Gg', 'RPcgpHHFYf8', 'd2gG8vis7EQ', '-gDAS08QjMY', 'x91urY8K62Y', 'ql7ArflgWds', 'yv_7y3ex95E', 'crKuMAH6wXo', '_75jDmg7TfI', 'TnrmlImXtmE', '3vYIuizfO5Y', 'nljHjj9U2HM', 'n40e0IMsE2Y', 'B18cUmHw550', 'tkugujUl03w']

# %% [markdown]
# ## Important
#
# This tutorial is just showing how to scrape each item from a list.
# If you want to scrape just one video transcript, delete the cell below and write this:
#
# - url = 'insert youtube-id here'
# - YouTubeTranscriptApi.get_transcript(url)
#
# Yeah. Simple as that. This is a simple thing to do.
#
# Now, let's run this cell:

# %%
transcript_list = [YouTubeTranscriptApi.get_transcript(i) for i in yt_links]

# %% [markdown]
# ## Did you get an error?
#
# - Yes? If it gives an error saying that one of the list items do not have transcripts, You'll just have to remove that. It's a bummer but you can't scrape something that is not there.
#
# - No Errors? (or you fixed it) Good. Move on. Run the next cell to create a dataframe:

# %%
df = [pd.DataFrame(s) for s in transcript_list]

# %% [markdown]
# Wanna check how cool your dataframe is?

# %%
df

# %% [markdown]
# ## Here's the problematic situation...
#
# These transcripts, by their nature, need to be in seperate files by nature. You can store it in one Excel file just like me if you don't need a lot of documents, and you're good with spreadsheets, or if you want every single document,
#
# **Delete this part of the code below:**
# - df2 = df.copy()
# - with pd.ExcelWriter('output.xlsx') as writer:
#
# **Change this --->** df[0].to_excel(writer, sheet_name= "United Kingdom")
#
# **to this --->** df[0].to_csv("United Kingdom.csv")
#
# ...and apply to the others like df[1], df[2] etc.
# I'd recommend going them through carefully if this is going to be a scientific project.

# %%
df2 = df.copy()
with pd.ExcelWriter('output.xlsx') as writer: 
    df[0].to_excel(writer, sheet_name= "United Kingdom")
    df[1].to_excel(writer, sheet_name= "United States")
    df[2].to_excel(writer, sheet_name= "Philippines")
    df[3].to_excel(writer, sheet_name= "Israel")
    df[4].to_excel(writer, sheet_name= "Poland")
    df[5].to_excel(writer, sheet_name= "Iran")
    df[6].to_excel(writer, sheet_name= "United Nations")
    df[7].to_excel(writer, sheet_name= "Ukraine")
    df[8].to_excel(writer, sheet_name= "Pakistan")
    df[9].to_excel(writer, sheet_name= "Ethiopia")
    df[10].to_excel(writer, sheet_name= "Solomon Islands")
    df[11].to_excel(writer, sheet_name= "China")
    df[12].to_excel(writer, sheet_name= "Papua New Guinea")
    df[13].to_excel(writer, sheet_name= "Kenya")
    df[14].to_excel(writer, sheet_name= "Cuba")
    df[15].to_excel(writer, sheet_name= "Nigeria")
    df[16].to_excel(writer, sheet_name= "Zimbabwe")
    df[17].to_excel(writer, sheet_name= "Cameroon")
    df[18].to_excel(writer, sheet_name= "Barbados")
    df[19].to_excel(writer, sheet_name= "New Zealand")
    df[20].to_excel(writer, sheet_name= "Rwanda")
    df[21].to_excel(writer, sheet_name= "State of Palestine")
    df[22].to_excel(writer, sheet_name= "Ghana")
    df[23].to_excel(writer, sheet_name= "Zambia")
    df[24].to_excel(writer, sheet_name= "Serbia")
    df[25].to_excel(writer, sheet_name= "Laos")
    df[26].to_excel(writer, sheet_name= "Marshall Islands")
    df[27].to_excel(writer, sheet_name= "Nauru")
    df[28].to_excel(writer, sheet_name= "Germany")
    df[29].to_excel(writer, sheet_name= "South Sudan")
    df[30].to_excel(writer, sheet_name= "France")
    df[31].to_excel(writer, sheet_name= "South Korea")
    df[32].to_excel(writer, sheet_name= "South Africa")
    df[33].to_excel(writer, sheet_name= "Hungary")
    df[34].to_excel(writer, sheet_name= "Liberia")
    df[35].to_excel(writer, sheet_name= "Senegal")
    df[36].to_excel(writer, sheet_name= "Samoa")
    df[37].to_excel(writer, sheet_name= "Australia")
    df[38].to_excel(writer, sheet_name= "Turkey")
    df[39].to_excel(writer, sheet_name= "Japan")
    df[40].to_excel(writer, sheet_name= "Colombia")
    df[41].to_excel(writer, sheet_name= "Jordan")
    df[42].to_excel(writer, sheet_name= "Malawi")
    df[43].to_excel(writer, sheet_name= "Russia")
    df[44].to_excel(writer, sheet_name= "Saint Kitts and Nevis")
    df[45].to_excel(writer, sheet_name= "Kazakhstan")
    df[46].to_excel(writer, sheet_name= "Uganda")
    df[47].to_excel(writer, sheet_name= "Mexico")
    df[48].to_excel(writer, sheet_name= "Benin")
    df[49].to_excel(writer, sheet_name= "Brazil")
    df[50].to_excel(writer, sheet_name= "Mali")
    df[51].to_excel(writer, sheet_name= "Greece")
    df[52].to_excel(writer, sheet_name= "Somalia")
    df[53].to_excel(writer, sheet_name= "United Nations")
    df[54].to_excel(writer, sheet_name= "UAE")
    df[55].to_excel(writer, sheet_name= "Central African Republic")
    df[56].to_excel(writer, sheet_name= "El Salvador")
    df[57].to_excel(writer, sheet_name= "Switzerland")
    df[58].to_excel(writer, sheet_name= "Fiji")
    df[59].to_excel(writer, sheet_name= "Cyprus")
    df[60].to_excel(writer, sheet_name= "Italy")
    df[61].to_excel(writer, sheet_name= "Honduras")
    df[62].to_excel(writer, sheet_name= "Gambia")
    df[63].to_excel(writer, sheet_name= "Gabon")
    df[64].to_excel(writer, sheet_name= "Morocco")
    df[65].to_excel(writer, sheet_name= "Namibia")
    df[66].to_excel(writer, sheet_name= "Congo Democratic Republic")
    df[67].to_excel(writer, sheet_name= "Syria")
    df[68].to_excel(writer, sheet_name= "Bangladesh")
    df[69].to_excel(writer, sheet_name= "Bahrain")
    df[70].to_excel(writer, sheet_name= "Netherlands")
    df[71].to_excel(writer, sheet_name= "Sierra Leone")
    df[72].to_excel(writer, sheet_name= "Kuwait")
    df[73].to_excel(writer, sheet_name= "Saint Lucia")
    df[74].to_excel(writer, sheet_name= "Mongolia")
    df[75].to_excel(writer, sheet_name= "Argentina")
    df[76].to_excel(writer, sheet_name= "Botswana")
    df[77].to_excel(writer, sheet_name= "Albania")
    df[78].to_excel(writer, sheet_name= "Bhutan")
    df[79].to_excel(writer, sheet_name= "Libya")
    df[80].to_excel(writer, sheet_name= "United Nations")
    df[81].to_excel(writer, sheet_name= "European Union")
    df[82].to_excel(writer, sheet_name= "Eswatini")
    df[83].to_excel(writer, sheet_name= "Indonesia")
    df[84].to_excel(writer, sheet_name= "Eritrea")
    df[85].to_excel(writer, sheet_name= "Equatorial Guinea")
    df[86].to_excel(writer, sheet_name= "Canada")
    df[87].to_excel(writer, sheet_name= "Pakistan")
    df[88].to_excel(writer, sheet_name= "Nicaragua")
    df[89].to_excel(writer, sheet_name= "Lithuania")
    df[90].to_excel(writer, sheet_name= "India")
    df[91].to_excel(writer, sheet_name= "Peru")
    df[92].to_excel(writer, sheet_name= "Luxembourg")
    df[93].to_excel(writer, sheet_name= "Vanuatu")
    df[94].to_excel(writer, sheet_name= "Finland")
    df[95].to_excel(writer, sheet_name= "Micronesia")
    df[96].to_excel(writer, sheet_name= "Cambodia")
    df[97].to_excel(writer, sheet_name= "Tanzania")
    df[98].to_excel(writer, sheet_name= "Kyrgyzstan")
    df[99].to_excel(writer, sheet_name= "Viet Nam")
    df[100].to_excel(writer, sheet_name= "Belize")
    df[101].to_excel(writer, sheet_name= "Latvia")
    df[102].to_excel(writer, sheet_name= "Dominica")
    df[103].to_excel(writer, sheet_name= "Slovakia")
    df[104].to_excel(writer, sheet_name= "Qatar")
    df[105].to_excel(writer, sheet_name= "Antigua and Barbuda")
    df[106].to_excel(writer, sheet_name= "Spain")
    df[107].to_excel(writer, sheet_name= "Slovenia")
    df[108].to_excel(writer, sheet_name= "Lebanon")
    df[109].to_excel(writer, sheet_name= "Costa Rica")
    df[110].to_excel(writer, sheet_name= "Slovenia")
    df[111].to_excel(writer, sheet_name= "Costa Rica")
    df[112].to_excel(writer, sheet_name= "Sudan")
    df[113].to_excel(writer, sheet_name= "Malaysia")
    df[114].to_excel(writer, sheet_name= "Georgia")
    df[115].to_excel(writer, sheet_name= "Mauritius")
    df[116].to_excel(writer, sheet_name= "Guinea-Bissau")
    df[117].to_excel(writer, sheet_name= "Tonga")
    df[118].to_excel(writer, sheet_name= "Nepal")
    df[119].to_excel(writer, sheet_name= "Romania")
    df[120].to_excel(writer, sheet_name= "Algeria")
    df[121].to_excel(writer, sheet_name= "Saint Vincent & the Grenadines")
    df[122].to_excel(writer, sheet_name= "Guatemala")
    df[123].to_excel(writer, sheet_name= "Thailand")
    df[124].to_excel(writer, sheet_name= "Belgium")
    df[125].to_excel(writer, sheet_name= "Côte d'Ivoire")
    df[126].to_excel(writer, sheet_name= "India")
    df[127].to_excel(writer, sheet_name= "Timor-Leste")
    df[128].to_excel(writer, sheet_name= "Chile")
    df[129].to_excel(writer, sheet_name= "Grenada")
    df[130].to_excel(writer, sheet_name= "Angola")
    df[131].to_excel(writer, sheet_name= "Croatia")
    df[132].to_excel(writer, sheet_name= "Montenegro")
    df[133].to_excel(writer, sheet_name= "Jamaica")
    df[134].to_excel(writer, sheet_name= "Belgium")
    df[135].to_excel(writer, sheet_name= "Lesotho")
    df[136].to_excel(writer, sheet_name= "Palau")
    df[137].to_excel(writer, sheet_name= "Liechtenstein")
    df[138].to_excel(writer, sheet_name= "Nepal")
    df[139].to_excel(writer, sheet_name= "Niger")
    df[140].to_excel(writer, sheet_name= "Guyana")
    df[141].to_excel(writer, sheet_name= "Austria")
    df[142].to_excel(writer, sheet_name= "Singapore")
    df[143].to_excel(writer, sheet_name= "Chad")
    df[144].to_excel(writer, sheet_name= "Iraq")
    df[145].to_excel(writer, sheet_name= "Bahamas")
    df[146].to_excel(writer, sheet_name= "Panama")
    df[147].to_excel(writer, sheet_name= "Panama")
    df[148].to_excel(writer, sheet_name= "Oman")
    df[149].to_excel(writer, sheet_name= "Yemen")
    df[150].to_excel(writer, sheet_name= "Iceland")
    df[151].to_excel(writer, sheet_name= "Turkmenistan")
    df[152].to_excel(writer, sheet_name= "Suriname")
    df[153].to_excel(writer, sheet_name= "Monaco")
    df[154].to_excel(writer, sheet_name= "Kiribati")
    df[155].to_excel(writer, sheet_name= "Mozambique")
    df[156].to_excel(writer, sheet_name= "Andorra")
    df[157].to_excel(writer, sheet_name= "Burundi")
    df[158].to_excel(writer, sheet_name= "Cabo Verde")
    df[159].to_excel(writer, sheet_name= "Tuvalu")
    df[160].to_excel(writer, sheet_name= "Madagascar")
    df[161].to_excel(writer, sheet_name= "Macedonia")
    df[162].to_excel(writer, sheet_name= "Tajikistan")
    df[163].to_excel(writer, sheet_name= "Portugal")
    df[164].to_excel(writer, sheet_name= "Uruguay")
    df[165].to_excel(writer, sheet_name= "UNGA President")
    df[166].to_excel(writer, sheet_name= "Estonia")
    df[167].to_excel(writer, sheet_name= "Norway")
    df[168].to_excel(writer, sheet_name= "Bolivia")
    df[169].to_excel(writer, sheet_name= "Paraguay")
    df[170].to_excel(writer, sheet_name= "Czech Republic")
    df[171].to_excel(writer, sheet_name= "Uzbekistan")
    df[172].to_excel(writer, sheet_name= "Bosnia and Herzegovina")
    df[173].to_excel(writer, sheet_name= "Maldives")
    df[174].to_excel(writer, sheet_name= "Sri Lanka")
    df[175].to_excel(writer, sheet_name= "Ecuador")
    df[176].to_excel(writer, sheet_name= "Ireland")
    df[177].to_excel(writer, sheet_name= "Saudi Arabia")
    df[178].to_excel(writer, sheet_name= "Dominican Republic")
    df[179].to_excel(writer, sheet_name= "Djibouti")
    df[180].to_excel(writer, sheet_name= "Moldova")
    df[181].to_excel(writer, sheet_name= "Togo")
    df[182].to_excel(writer, sheet_name= "Belarus")
    df[183].to_excel(writer, sheet_name= "Malta")
    df[184].to_excel(writer, sheet_name= "North Korea")
    df[185].to_excel(writer, sheet_name= "Azerbaijan")
    df[186].to_excel(writer, sheet_name= "Comoros")
    df[187].to_excel(writer, sheet_name= "Haiti")
    df[188].to_excel(writer, sheet_name= "Seychelles")
    df[189].to_excel(writer, sheet_name= "Ethiopia")
    df[190].to_excel(writer, sheet_name= "Sweden")
    df[191].to_excel(writer, sheet_name= "Brunei")
    df[192].to_excel(writer, sheet_name= "Mauritania")
    df[193].to_excel(writer, sheet_name= "Tunisia")
    df[194].to_excel(writer, sheet_name= "Trinidad and Tobago")
    df[195].to_excel(writer, sheet_name= "Guinea")
    df[196].to_excel(writer, sheet_name= "Bulgaria")
    df[197].to_excel(writer, sheet_name= "Egypt")
    df[198].to_excel(writer, sheet_name= "San Marino")
    df[199].to_excel(writer, sheet_name= "Venezuela")
    df[200].to_excel(writer, sheet_name= "Tanzania")
    df[201].to_excel(writer, sheet_name= "Republic of Congo")
    df[202].to_excel(writer, sheet_name= "Bhutan")
    df[203].to_excel(writer, sheet_name= "Canada")
    df[204].to_excel(writer, sheet_name= "Australia")
    df[205].to_excel(writer, sheet_name= "Côte d'Ivoire")
    df[206].to_excel(writer, sheet_name= "Saint Vincent & Grenadines")
    df[207].to_excel(writer, sheet_name= "Solomon Islands")
    df[208].to_excel(writer, sheet_name= "Mexico")
    df[209].to_excel(writer, sheet_name= "Sweden")
    df[210].to_excel(writer, sheet_name= "Cuba")
    df[211].to_excel(writer, sheet_name= "Maldives")
    df[212].to_excel(writer, sheet_name= "Czech Republic")
    df[213].to_excel(writer, sheet_name= "Burundi")
    df[214].to_excel(writer, sheet_name= "Saudi Arabia")
    df[215].to_excel(writer, sheet_name= "Eswatini")
    df[216].to_excel(writer, sheet_name= "Saint Lucia")
    df[217].to_excel(writer, sheet_name= "Palau")
    df[218].to_excel(writer, sheet_name= "Mauritius")
    df[219].to_excel(writer, sheet_name= "Congo Democratic Republic")
